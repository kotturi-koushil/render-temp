# %%
import pandas as pd
import numpy as np

# to visualize the dataset
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# To preprocess the data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import make_pipeline
# import iterative imputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
# machine learning
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
# for classification tasks
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier

from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
#metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.metrics import mean_absolute_error, precision_score, r2_score, mean_squared_error
# impot pipeline
from sklearn.pipeline import Pipeline
# ignore warnings   
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv(r"C:\Users\shashank\majorfinal.csv")

# %%
#Checking the dataset:

# %%
print(df.shape)
# Out:
# (920, 17)

# %%
df.head()
# Out:
#    Unnamed: 0  id  age     sex    dataset               cp  trestbps   chol  \
# 0           0   1   63    Male  Cleveland   typical angina     145.0  233.0
# 1           1   2   67    Male  Cleveland     asymptomatic     160.0  286.0
# 2           2   3   67    Male  Cleveland     asymptomatic     120.0  229.0
# 3           3   4   37    Male  Cleveland      non-anginal     130.0  250.0
# 4           4   5   41  Female  Cleveland  atypical angina     130.0  204.0
#
#      fbs         restecg  thalch  exang  oldpeak        slope   ca  num  BMI
# 0   True  lv hypertrophy   150.0  False      2.3  downsloping  0.0    0   18
# 1  False  lv hypertrophy   108.0   True      1.5         flat  3.0    2   29
# 2  False  lv hypertrophy   129.0   True      2.6         flat  2.0    1   22
# 3  False          normal   187.0  False      3.5  downsloping  0.0    0   20
# 4  False  lv hypertrophy   172.0  False      1.4    upsloping  0.0    0   18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  920 non-null    int64
#  1   id          920 non-null    int64
#  2   age         920 non-null    int64
#  3   sex         920 non-null    object
#  4   dataset     920 non-null    object
#  5   cp          920 non-null    object
#  6   trestbps    861 non-null    float64
#  7   chol        890 non-null    float64
#  8   fbs         830 non-null    object
#  9   restecg     918 non-null    object
#  10  thalch      865 non-null    float64
#  11  exang       865 non-null    object
#  12  oldpeak     858 non-null    float64
#  13  slope       611 non-null    object
#  14  ca          309 non-null    float64
#  15  num         920 non-null    int64
#  16  BMI         920 non-null    int64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 122.3+ KB

# %%
print(df.isnull().sum().sort_values(ascending=False))
# Out:
# ca            611
# slope         309
# fbs            90
# oldpeak        62
# trestbps       59
# thalch         55
# exang          55
# chol           30
# restecg         2
# num             0
# Unnamed: 0      0
# id              0
# cp              0
# dataset         0
# sex             0
# age             0
# BMI             0
# dtype: int64

# %%
#Performing EDA

# %%
sns.histplot(df['age'], kde=True)
plt.axvline(df['age'].mean(), color='red')
plt.axvline(df['age'].median(), color='green')
plt.axvline(df['age'].mode()[0], color='blue')

# print the value of mean, median and mode of age column
print('Mean:', df['age'].mean())
print('Median:', df['age'].median())
print('Mode:', df['age'].mode()[0])
# Out:
# Mean: 53.51086956521739
# Median: 54.0
# Mode: 54

# %%
fig = px.histogram(data_frame=df, x='age', color='sex')
fig.show()

# %%
print(df['sex'].value_counts())
# Out:
# Male      726
# Female    194
# Name: sex, dtype: int64

# %%
male_count = 726
female_count = 194
total_count = male_count + female_count

# calculate percentages
male_percentage = (male_count / total_count) * 100
female_percentage = (female_count / total_count) * 100

# display the results
print(f"Male percentage in the data: {male_percentage:.2f}%")
print(f"Female Percentage in the data: {female_percentage:.2f}%")
# Out:
# Male percentage in the data: 78.91%
# Female Percentage in the data: 21.09%

# %%
df['sex'].value_counts().plot(kind='pie',autopct='%2.f')
# Out:
# <Axes: ylabel='sex'>

# %%
df['dataset'].unique()
# Out:
# array(['Cleveland', 'Hungary', 'Switzerland', 'VA Long Beach'],
#       dtype=object)

# %%
df['dataset'].value_counts()
# Out:
# Cleveland        304
# Hungary          293
# VA Long Beach    200
# Switzerland      123
# Name: dataset, dtype: int64

# %%
print(df.groupby('sex')['dataset'].value_counts())
# Out:
# sex     dataset
# Female  Cleveland         97
#         Hungary           81
#         Switzerland       10
#         VA Long Beach      6
# Male    Hungary          212
#         Cleveland        207
#         VA Long Beach    194
#         Switzerland      113
# Name: dataset, dtype: int64

# %%
df.groupby('dataset')['num'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='dataset,num'>

# %%
df['trestbps'].describe()
# Out:
# count    861.000000
# mean     132.132404
# std       19.066070
# min        0.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
print(sns.histplot(df['trestbps'], kde=True))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# make a plot of trestbps column using plotly and coloring this by dataset column
fig = px.histogram(data_frame=df, x='trestbps', color='dataset')
fig.show()

# %%
df.groupby(df['sex'])[['trestbps']].describe()
# Out:
#        trestbps
#           count        mean        std   min    25%    50%    75%    max
# sex
# Female    192.0  132.093750  19.509202  94.0  120.0  130.0  140.0  200.0
# Male      669.0  132.143498  18.951807   0.0  120.0  130.0  140.0  200.0

# %%
sns.histplot(df['chol'], kde=True)
plt.axvline(df['chol'].mean(), color='red')
plt.axvline(df['chol'].median(), color='green')
plt.axvline(df['chol'].mode()[0], color='blue')

# %%
df.groupby(df['sex'])[['chol']].describe()
# Out:
#          chol
#         count        mean         std  min    25%    50%    75%    max
# sex
# Female  187.0  241.481283   86.291226  0.0  204.0  244.0  291.0  564.0
# Male    703.0  187.864865  113.858400  0.0  156.5  220.0  263.0  603.0

# %%
df['fbs'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 920 entries, 0 to 919
# Series name: fbs
# Non-Null Count  Dtype
# --------------  -----
# 830 non-null    object
# dtypes: object(1)
# memory usage: 7.3+ KB

# %%
df['fbs'].value_counts()
# Out:
# False    692
# True     138
# Name: fbs, dtype: int64

# %%
df.groupby(df['fbs'])[['sex']].value_counts()
# Out:
# fbs    sex
# False  Male      528
#        Female    164
# True   Male      119
#        Female     19
# dtype: int64

# %%
df['restecg'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 920 entries, 0 to 919
# Series name: restecg
# Non-Null Count  Dtype
# --------------  -----
# 918 non-null    object
# dtypes: object(1)
# memory usage: 7.3+ KB

# %%
df['restecg'].value_counts()
# Out:
# normal              551
# lv hypertrophy      188
# st-t abnormality    179
# Name: restecg, dtype: int64

# %%
df.groupby(df['restecg'])[['sex']].value_counts()
# Out:
# restecg           sex
# lv hypertrophy    Male      141
#                   Female     47
# normal            Male      432
#                   Female    119
# st-t abnormality  Male      151
#                   Female     28
# dtype: int64

# %%
df.groupby(df['restecg'])[['dataset']].value_counts()
# Out:
# restecg           dataset
# lv hypertrophy    Cleveland        149
#                   VA Long Beach     27
#                   Switzerland        7
#                   Hungary            5
# normal            Hungary          235
#                   Cleveland        151
#                   Switzerland       85
#                   VA Long Beach     80
# st-t abnormality  VA Long Beach     93
#                   Hungary           52
#                   Switzerland       30
#                   Cleveland          4
# dtype: int64

# %%
counts = df.groupby(df['restecg'])[['dataset','sex']].value_counts().unstack()
print(counts.plot.bar())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
df['thalch'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 920 entries, 0 to 919
# Series name: thalch
# Non-Null Count  Dtype
# --------------  -----
# 865 non-null    float64
# dtypes: float64(1)
# memory usage: 7.3 KB

# %%
print(sns.histplot(df['thalch'],kde = True))
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
 # `chol` (serum cholesterol in mg/dl)
sns.histplot(df['thalch'], kde=True)
plt.axvline(df['thalch'].mean(), color='red')
plt.axvline(df['thalch'].median(), color='green')
plt.axvline(df['thalch'].mode()[0], color='blue')

# %%
df['exang'].value_counts()
# Out:
# False    528
# True     337
# Name: exang, dtype: int64

# %%
df.groupby(df['exang'])[['sex']].value_counts()
# Out:
# exang  sex
# False  Male      379
#        Female    149
# True   Male      294
#        Female     43
# dtype: int64

# %%
df['oldpeak'].describe()
# Out:
# count    858.000000
# mean       0.878788
# std        1.091226
# min       -2.600000
# 25%        0.000000
# 50%        0.500000
# 75%        1.500000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
df['slope'].value_counts()
# Out:
# flat           345
# upsloping      203
# downsloping     63
# Name: slope, dtype: int64

# %%
df.groupby(df['slope'])['restecg'].value_counts()
# Out:
# slope        restecg
# downsloping  normal               31
#              lv hypertrophy       17
#              st-t abnormality     15
# flat         normal              206
#              lv hypertrophy       84
#              st-t abnormality     55
# upsloping    normal              116
#              lv hypertrophy       64
#              st-t abnormality     22
# Name: restecg, dtype: int64

# %%
df['ca'].value_counts()
# Out:
# 0.0    181
# 1.0     67
# 2.0     41
# 3.0     20
# Name: ca, dtype: int64

# %%
print(df['num'].unique())
# Out:
# [0 2 1 3 4]

# %%
df['num'].value_counts()
# Out:
# 0    411
# 1    265
# 2    109
# 3    107
# 4     28
# Name: num, dtype: int64

# %%
df.groupby(df['num'])[['dataset']].value_counts()
# Out:
# num  dataset
# 0    Hungary          187
#      Cleveland        165
#      VA Long Beach     51
#      Switzerland        8
# 1    Hungary          106
#      VA Long Beach     56
#      Cleveland         55
#      Switzerland       48
# 2    VA Long Beach     41
#      Cleveland         36
#      Switzerland       32
# 3    VA Long Beach     42
#      Cleveland         35
#      Switzerland       30
# 4    Cleveland         13
#      VA Long Beach     10
#      Switzerland        5
# dtype: int64

# %%
#Understading the correlation

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df['restecg'] = df['restecg'].apply(lambda x:0 if x=='normal' else( 1 if x=='lv hypertrophy' else 2) )

# %%
df['slope']= df['slope'].apply(lambda x:0 if x=='flat' else( 1 if x=='upsloping' else 2) )

# %%
#df.drop(['id','dataset'],axis=1,inplace=True)

# %%
#handling The Outliers
df
# Out:
#      Unnamed: 0   id  age     sex        dataset               cp  trestbps  \
# 0             0    1   63    Male      Cleveland   typical angina     145.0
# 1             1    2   67    Male      Cleveland     asymptomatic     160.0
# 2             2    3   67    Male      Cleveland     asymptomatic     120.0
# 3             3    4   37    Male      Cleveland      non-anginal     130.0
# 4             4    5   41  Female      Cleveland  atypical angina     130.0
# 57           57   58   41    Male      Cleveland     asymptomatic     110.0
# 58           58   59   54    Male      Cleveland      non-anginal     125.0
# 59           59   60   51    Male      Cleveland   typical angina     125.0
# 60           60   61   51  Female      Cleveland     asymptomatic     130.0
# 61           61   62   46  Female      Cleveland      non-anginal     142.0
# 62           62   63   58    Male      Cleveland     asymptomatic     128.0
# 63           63   64   54  Female      Cleveland      non-anginal     135.0
# 64           64   65   54    Male      Cleveland     asymptomatic     120.0
# 65           65   66   60    Male      Cleveland     asymptomatic     145.0
# 66           66   67   60    Male      Cleveland      non-anginal     140.0
# 67           67   68   54    Male      Cleveland      non-anginal     150.0
# 68           68   69   59    Male      Cleveland     asymptomatic     170.0
# 69           69   70   46    Male      Cleveland      non-anginal     150.0
# 70           70   71   65  Female      Cleveland      non-anginal     155.0
# 71           71   72   67    Male      Cleveland     asymptomatic     125.0
# 72           72   73   62    Male      Cleveland     asymptomatic     120.0
# 73           73   74   65    Male      Cleveland     asymptomatic     110.0
# 74           74   75   44    Male      Cleveland     asymptomatic     110.0
# 75           75   76   65  Female      Cleveland      non-anginal     160.0
# 76           76   77   60    Male      Cleveland     asymptomatic     125.0
# 77           77   78   51  Female      Cleveland      non-anginal     140.0
# 78           78   79   48    Male      Cleveland  atypical angina     130.0
# 79           79   80   58    Male      Cleveland     asymptomatic     150.0
# 80           80   81   45    Male      Cleveland     asymptomatic     104.0
# 81           81   82   53  Female      Cleveland     asymptomatic     130.0
# 82           82   83   39    Male      Cleveland      non-anginal     140.0
# 83           83   84   68    Male      Cleveland      non-anginal     180.0
# 84           84   85   52    Male      Cleveland  atypical angina     120.0
# 85           85   86   44    Male      Cleveland      non-anginal     140.0
# 86           86   87   47    Male      Cleveland      non-anginal     138.0
# 87           87   88   53  Female      Cleveland      non-anginal     128.0
# 88           88   89   53  Female      Cleveland     asymptomatic     138.0
# 89           89   90   51  Female      Cleveland      non-anginal     130.0
# 90           90   91   66    Male      Cleveland     asymptomatic     120.0
# 91           91   92   62  Female      Cleveland     asymptomatic     160.0
# 92           92   93   62    Male      Cleveland      non-anginal     130.0
# 93           93   94   44  Female      Cleveland      non-anginal     108.0
# 94           94   95   63  Female      Cleveland      non-anginal     135.0
# 95           95   96   52    Male      Cleveland     asymptomatic     128.0
# 96           96   97   59    Male      Cleveland     asymptomatic     110.0
# 97           97   98   60  Female      Cleveland     asymptomatic     150.0
# 98           98   99   52    Male      Cleveland  atypical angina     134.0
# 99           99  100   48    Male      Cleveland     asymptomatic     122.0
# 100         100  101   45    Male      Cleveland     asymptomatic     115.0
# 101         101  102   34    Male      Cleveland   typical angina     118.0
# 102         102  103   57  Female      Cleveland     asymptomatic     128.0
# 103         103  104   71  Female      Cleveland      non-anginal     110.0
# 104         104  105   49    Male      Cleveland      non-anginal     120.0
# 105         105  106   54    Male      Cleveland  atypical angina     108.0
# 106         106  107   59    Male      Cleveland     asymptomatic     140.0
# 107         107  108   57    Male      Cleveland      non-anginal     128.0
# 108         108  109   61    Male      Cleveland     asymptomatic     120.0
# 109         109  110   39    Male      Cleveland     asymptomatic     118.0
# 591         591  592   52    Male        Hungary     asymptomatic     140.0
# 592         592  593   52    Male        Hungary     asymptomatic     160.0
# 593         593  594   54  Female        Hungary      non-anginal     130.0
# 594         594  595   56    Male        Hungary     asymptomatic     155.0
# 595         595  596   58  Female        Hungary  atypical angina     180.0
# 596         596  597   65    Male        Hungary     asymptomatic     130.0
# 597         597  598   32    Male    Switzerland   typical angina      95.0
# 598         598  599   34    Male    Switzerland     asymptomatic     115.0
# 599         599  600   35    Male    Switzerland     asymptomatic       NaN
# 600         600  601   36    Male    Switzerland     asymptomatic     110.0
# 601         601  602   38  Female    Switzerland     asymptomatic     105.0
# 602         602  603   38  Female    Switzerland     asymptomatic     110.0
# 603         603  604   38    Male    Switzerland      non-anginal     100.0
# 604         604  605   38    Male    Switzerland      non-anginal     115.0
# 605         605  606   38    Male    Switzerland     asymptomatic     135.0
# ...
# 707    0.0   True        2   122.0  False      NaN      2  NaN    3   39
# 708    0.0    NaN        0    90.0  False      0.0      2  NaN    1   25
# 709    0.0  False        0   108.0   True      2.0      0  NaN    3   34
# 710    0.0  False        1   125.0  False      0.0      0  NaN    2   29
# 711    0.0  False        2   120.0   True      0.0      1  NaN    3   38
# 712    0.0    NaN        0   136.0  False      1.8      1  NaN    1   21
# 713    0.0  False        0   130.0  False      0.0      0  NaN    1   22
# 714    0.0  False        2     NaN    NaN      NaN      2  NaN    3   36
# 715    0.0  False        2    92.0   True      0.0      0  NaN    1   20
# 716    0.0   True        0   157.0   True      2.0      0  NaN    3   39
# 717    0.0    NaN        1   114.0  False      1.6      0  2.0    0   18
# 718    0.0  False        2   121.0  False      0.0      1  NaN    1   23
# 719    0.0    NaN        2   123.0  False      1.3      1  NaN    1   19
# 720  260.0  False        2   112.0   True      3.0      0  NaN    2   25
# 721  209.0  False        2   127.0  False      0.0      2  NaN    0   20
# 722  218.0  False        2   140.0   True      1.5      2  NaN    2   26
# 723  228.0  False        2   149.0   True      2.5      1  NaN    1   21
# 724  213.0   True        1    99.0   True      1.3      0  NaN    0   18
# 725    0.0  False        2   120.0  False     -0.5      1  NaN    0   18
# 726  236.0   True        2   105.0   True      0.0      2  NaN    3   34
# 727    0.0  False        2   140.0   True      1.5      0  NaN    0   18
# 728    0.0    NaN        0   141.0   True      2.0      1  NaN    3   38
# 729  267.0   True        2   157.0  False      0.5      0  NaN    1   20
# 730  166.0  False        2   140.0  False      0.0      2  NaN    0   20
# 731    0.0  False        2   117.0   True      1.0      0  NaN    1   23
# 732    0.0  False        0   120.0   True      0.5      0  NaN    1   22
# 733    0.0  False        1     NaN    NaN      NaN      2  NaN    1   20
# 734    0.0   True        2   148.0   True      1.0      0  NaN    1   18
# 735  220.0  False        2    86.0  False      0.0      2  NaN    0   18
# 736  177.0  False        0    84.0   True      2.5      2  NaN    4   36
# 737  236.0  False        0   125.0   True      2.0      0  NaN    1   18
# 738    0.0  False        2   120.0  False      1.5      2  NaN    0   20
# 739    0.0  False        2   118.0   True      0.0      2  NaN    0   20
# 740    0.0  False        0   124.0  False      1.0      1  NaN    2   26
# 883  289.0   True        2     NaN    NaN      NaN      2  NaN    3   34
# 884    NaN   True        1     NaN    NaN      NaN      2  NaN    1   22
# 885    NaN  False        0   159.0   True      1.5      1  NaN    3   36
# 886  216.0   True        1    84.0   True      0.0      2  NaN    2   30
# 887  271.0  False        1     NaN    NaN      NaN      2  NaN    0   19
# 888  244.0   True        2     NaN    NaN      NaN      2  NaN    2   27
# 889  285.0   True        2   120.0  False      0.8      2  NaN    1   23
# 890  243.0  False        0   122.0   True      2.0      0  NaN    1   21
# 891  240.0  False        1   165.0  False      1.0      0  NaN    0   20
# 892  219.0  False        2   122.0   True      2.0      0  NaN    3   37
# 893  237.0   True        0    94.0  False      0.0      2  NaN    1   23
# 894  165.0  False        2     NaN    NaN      NaN      2  NaN    0   19
# 895  213.0  False        2   110.0  False      0.0      2  NaN    0   19
# 896  287.0   True        1   150.0   True      2.0      2  NaN    4   32
# 897  258.0   True        1   130.0  False      0.0      2  NaN    2   26
# 898  256.0   True        1   113.0   True      1.0      1  NaN    3   31
# 899  186.0   True        1   140.0   True      0.5      0  NaN    1   25
# 900  264.0  False        1   100.0  False      0.0      2  NaN    1   19
# 901    NaN  False        2     NaN    NaN      NaN      2  NaN    0   19
# 902  226.0  False        1   127.0   True      1.7      2  NaN    1   18
# 903  203.0   True        0    98.0  False      1.5      0  NaN    1   20
# 904  207.0  False        2    96.0   True      1.0      0  NaN    0   20
# 905  284.0  False        0     NaN    NaN      NaN      2  NaN    1   21
# 906  337.0  False        0    98.0   True      0.0      2  NaN    3   34
# 907  219.0  False        2   118.0   True      0.0      2  NaN    2   30
# 908  310.0  False        0   112.0   True      1.5      2  NaN    2   26
# 909  254.0   True        0   151.0   True      0.0      2  NaN    0   19
# 910  258.0   True        1    96.0  False      1.0      1  NaN    0   20
# 911  254.0   True        2   108.0   True      3.0      0  NaN    4   36
# 912  300.0   True        2   128.0   True      1.5      0  NaN    3   31
# 913  170.0  False        2   138.0   True      0.0      2  NaN    1   18
# 914  310.0  False        0   126.0  False      0.0      2  NaN    2   30
# 915  333.0   True        2   154.0  False      0.0      2  NaN    1   19
# 916  139.0  False        2     NaN    NaN      NaN      2  NaN    0   19
# 917  223.0   True        2   100.0  False      0.0      2  NaN    2   27
# 918  385.0   True        1     NaN    NaN      NaN      2  NaN    0   20
# 919  254.0  False        1    93.0   True      0.0      2  NaN    1   21

# %%
import seaborn as sns
import pandas as pd

# Example data
data = pd.DataFrame({
    "Age": df['age'],
    "trestbps": df['trestbps'],
    "chol": df['chol'],
    "thalch":df['thalch'],
    "oldpeak":df['oldpeak'],
    "slope":df['slope'],
    "ca":df['ca']
    
})

# Plotting boxplots
sns.boxplot(data=data)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,3,1)
sns.boxplot(df['age'])

plt.subplot(2,3,2)
sns.boxplot(df['trestbps'])

plt.subplot(2,3,3)
sns.boxplot(df['chol'])

plt.subplot(2,3,4)
sns.boxplot(df['thalch'])

plt.subplot(2,3,5)
sns.boxplot(df['oldpeak'])

plt.subplot(2,3,6)
sns.boxplot(df['ca'])

# Show the plots
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,3,1)
sns.distplot(df['age'])

plt.subplot(2,3,2)
sns.distplot(df['trestbps'])

plt.subplot(2,3,3)
sns.distplot(df['chol'])

plt.subplot(2,3,4)
sns.distplot(df['thalch'])

plt.subplot(2,3,5)
sns.distplot(df['oldpeak'])

plt.subplot(2,3,6)
sns.distplot(df['ca'])

# Show the plots
plt.show()

# %%
upperthalch = df['thalch'].mean()+3*df['thalch'].std()
upperthalch
# Out:
# 215.3244942182772

# %%
lowerthalch = df['thalch'].mean() - 3 * df['thalch'].std()
lowerthalch
# Out:
# 59.76683526149155

# %%
df[(df['thalch']>215.32) | (df['thalch']<5)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, age, sex, dataset, cp, trestbps, chol, fbs, restecg, thalch, exang, oldpeak, slope, ca, num, BMI]
# Index: []

# %%
df['age'].skew()
# Out:
# -0.195993861608106

# %%
df['trestbps'].skew()
# Out:
# 0.21333446967212508

# %%
df['chol'].skew()
# Out:
# -0.6138360897370758

# %%
df['thalch'].skew()
# Out:
# -0.21111858073161133

# %%
df['oldpeak'].skew()
# Out:
# 1.0414266146339854

# %%
df['ca'].skew()
# Out:
# 1.1659778654172832

# %%
p25t = df['trestbps'].quantile(0.25)
p75t = df['trestbps'].quantile(0.75)
iqrt = p75t-p25t
uppert = p75t+iqrt
lowert = p25t-iqrt

# %%
uppert
# Out:
# 160.0

# %%
lowert
# Out:
# 100.0

# %%
df['trestbps'] = np.where(df['trestbps']>uppert,uppert,np.where(
df['trestbps']<lowert,lowert,df['trestbps']))

# %%
p25c = df['chol'].quantile(0.25)
p75c = df['chol'].quantile(0.75)
iqrc = p75c-p25c
upperc = p75c+iqrc
lowerc = p25c-iqrc

# %%
upperc
# Out:
# 361.0

# %%
lowerc
# Out:
# 82.0

# %%
df['chol'] = np.where(df['chol']>upperc,upperc,np.where(
df['chol']<lowerc,lowerc,df['chol']))

# %%
p25o = df['oldpeak'].quantile(0.25)
p75o = df['oldpeak'].quantile(0.75)
iqro = p75o-p25o
uppero = p75o+iqro
lowero = p25o-iqro

# %%
uppero
# Out:
# 3.0

# %%
lowero
# Out:
# -1.5

# %%
df['oldpeak'] = np.where(df['oldpeak']>uppero,uppero,np.where(df['oldpeak']<lowero,lowero,df['oldpeak']))

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,3,1)
sns.boxplot(df['age'])

plt.subplot(2,3,2)
sns.boxplot(df['trestbps'])

plt.subplot(2,3,3)
sns.boxplot(df['chol'])

plt.subplot(2,3,4)
sns.boxplot(df['thalch'])

plt.subplot(2,3,5)
sns.boxplot(df['oldpeak'])

plt.subplot(2,3,6)
sns.boxplot(df['ca'])

# Show the plots
plt.show()

# %%
df.drop(columns=['Unnamed: 0'],inplace =True)

# %%
df.columns
# Out:
# Index(['id', 'age', 'sex', 'dataset', 'cp', 'trestbps', 'chol', 'fbs',
#        'restecg', 'thalch', 'exang', 'oldpeak', 'slope', 'ca', 'num', 'BMI'],
#       dtype='object')

# %%
df.drop(columns=['dataset'],inplace=True)

# %%
df.drop(columns = ['id'],inplace = True)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(df.drop(['num'],axis=1),df['num'])

# %%
trf2= ColumnTransformer(transformers = [
    ('impute_bps_Chol_thal_ch_oldPeak_ca',SimpleImputer(),[3,4,7,9,11]),
    ('impute_fbs_restecg_exang_slope',SimpleImputer(strategy='most_frequent'),[5,6,8,10]),
    ('oc',OrdinalEncoder(categories=[['asymptomatic','non-anginal','atypical angina','typical angina']]),[2]),
    ('oh_sex_fbs_exang',OneHotEncoder(sparse=False,handle_unknown='ignore'),[1,5,8]),
],remainder='passthrough')

# %%
trf3 = StandardScaler()

# %%
pipe = make_pipeline(trf2,trf3)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,100,1000]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'knearestneighbors' : {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [1,3,5,30]
        }
    },
    'naive_bayes':{
        'model':GaussianNB(),
        'params':{
            
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=2, return_train_score=False)
    X = pipe.fit_transform(X_train)
    clf.fit(X,Y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
scores = pd.DataFrame(scores,columns=['model','best_score','best_params'])
scores
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 scores = []
# ----> 3 for model_name, mp in model_params.items():
#       4     clf =  GridSearchCV(mp['model'], mp['params'], cv=2, return_train_score=False)
#       5     X = pipe.fit_transform(X_train)
#
# NameError: name 'model_params' is not defined

# %%
X = df.drop('num',axis=1)
y = df['num']
# replace 1 with 0 and all others to 1
y = np.where((y == 1) | (y == 2) | (y == 3) | (y == 4), 1,0)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y)

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

model_params = {
    'svm': {
        'model': svm.SVC(),
        'params' : {
    
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,2,3]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(penalty='l2'),
        'params': {
            
        }
    },
    'knearestneighbors' : {
        'model': KNeighborsClassifier(),
        'params': {
            'n_neighbors': [1,3,5,30]
        }
    },
    'naive_bayes':{
        'model':GaussianNB(),
        'params':{
            
        }
    }
}

# %%
scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=2, return_train_score=False)
    X = pipe.fit_transform(X_train)
    clf.fit(X,Y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
scores = pd.DataFrame(scores,columns=['model','best_score','best_params'])
scores
# Out:
#                  model  best_score          best_params
# 0                  svm    0.872464                   {}
# 1        random_forest    0.866667  {'n_estimators': 3}
# 2  logistic_regression    0.871014                   {}
# 3    knearestneighbors    0.828986   {'n_neighbors': 5}
# 4          naive_bayes    0.855072                   {}

# %%
import joblib

# %%
trf5 = LogisticRegression()

# %%
last_pipe = make_pipeline(trf2,trf3,trf5)

# %%
last_pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('impute_bps_Chol_thal_ch_oldPeak_ca',
#                                                   SimpleImputer(),
#                                                   [3, 4, 7, 9, 11]),
#                                                  ('impute_fbs_restecg_exang_slope',
#                                                   SimpleImputer(strategy='most_frequent'),
#                                                   [5, 6, 8, 10]),
#                                                  ('oc',
#                                                   OrdinalEncoder(categories=[['asymptomatic',
#                                                                               'non-anginal',
#                                                                               'atypical '
#                                                                               'angina',
#                                                                               'typical '
#                                                                               'angina']]),
#                                                   [2]),
#                                                  ('oh_sex_fbs_exang',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False),
#                                                   [1, 5, 8])])),
#                 ('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %%
last_pipe.predict([[12.0, 'Male', 'typical angina', 200.0, 126.0, 1, 0.0, 82.0, 1, 5.0, 0.0, 3.0, 30.0]])
# Out:
# array([1])

# %%
len([63,'Male','typical angina',145.0,233.0,True,1,150.0,False,2.3,2,0.0,13])
# Out:
# 13

# %%
joblib.dump(last_pipe,'major_finalModel4.pkl')
# Out:
# ['major_finalModel4.pkl']

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2
